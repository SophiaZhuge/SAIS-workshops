# %% [markdown]
# #                                     SAIS Tutorial on Python Basics

# %% [markdown]
# This is our first program in python:

# %%
print("Hellow World")
# Out:
# Hellow World

# %% [markdown]
# ## Variables

# %%
x = 3

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# x          int     3

# %%
print(type(x)) # numbers without decimals = type integer
# Out:
# <class 'int'>

# %%
x = 5.7

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# x          float    5.7

# %%
print(type(x)) # float = numbers with decimals
# Out:
# <class 'float'>

# %%
a,b,c,d,f = 3,5,6.0,7.2,-3 # you can assign variables like this

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      3
# b          int      5
# c          float    6.0
# d          float    7.2
# f          int      -3
# x          float    5.7

# %%
s = "hellow how are you"

# %%
print(type(s)) # words or sentences = type string
# Out:
# <class 'str'>

# %% [markdown]
# ## Operators

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      3
# b          int      5
# c          float    6.0
# d          float    7.2
# f          int      -3
# s          str      hellow how are you
# x          float    5.7

# %%
sumOfaAndb = a+b

# %%
print(sumOfaAndb)
# Out:
# 8

# %%
v = ((a+d)**3)/4

# %%
print(v)
# Out:
# 265.30199999999996

# %%
# we can also use + to concatinate strings 
s1 = "hellow"
s2 = "world"
s = s1+s2
print(s)
# Out:
# hellowworld

# %%
10//3 # floor division ie. round down the calculation
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %%
_
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Python Arithmetic Operators

# %% [markdown]
# ![operators1.png](attachment:operators1.png)

# %% [markdown]
# ### Python a

# %% [markdown]
# ## Boolean

# %%
a = True
b = True
c = False

# %%
# %whos
# Out:
# Variable     Type     Data/Info
# -------------------------------
# a            bool     True
# b            bool     True
# c            bool     False
# d            float    7.2
# f            int      -3
# s            str      hellowworld
# s1           str      hellow
# s2           str      world
# sumOfaAndb   int      8
# v            float    265.30199999999996
# x            float    5.7

# %%
print(a and b)
print(a and c)
print(c and a)
# Out:
# True
# False
# False

# %%
d = a or c
print(d)
# Out:
# True

# %%
not(a)
# Out:
# False

# %%
t = not(d)

# %%
type(t)
# Out:
# bool

# %%
print(t)
# Out:
# False

# %%
not((a and b) or (c or d))
# Out:
# False

# %% [markdown]
# ## Comparisons

# %%
print(2<3)
# Out:
# True

# %%
c = 2<3
print(type(c))
print(c)
# Out:
# <class 'bool'>
# True

# %%
d = 3==4 # '=' means assignment, '==' means equal to

# %%
print(d)
# Out:
# False

# %%
3==3.0
# Out:
# True

# %%
x = 4
y = 9
z = 8.3
r = -3

# %%
(x<y) and (z<y) or (r==x)
# Out:
# True

# %%
(r==x) and (x<y) or (z>y)
# Out:
# False

# %%
(True or False) and False
# Out:
# False

# %%
print((not(2!=3) and True) or (False and True))
# Out:
# False

# %%
print(round(4.556))
# Out:
# 5

# %%
print(round(4.345))
# Out:
# 4

# %%
print(round(4.556389,3))
# Out:
# 4.556

# %%
B = divmod(27,5)

# %%
type(B)
# Out:
# tuple

# %%
print(B)
# Out:
# (5, 2)

# %%
B[0]
# Out:
# 5

# %%
B[1]
# Out:
# 2

# %% [markdown]
# ## More Python functions

# %%
isinstance(3,int)
# Out:
# True

# %%
isinstance(3.4,(float,int))
# Out:
# True

# %%
isinstance(2+3j,(int,float,str,complex))
# Out:
# True

# %%
pow(2,4)
# Out:
# 16

# %%
2**4
# Out:
# 16

# %%
pow(2,4,7)
# Out:
# 2

# %%
x = input("Enter a number :")
# Out:
# Enter a number :7

# %%
type(x)
# Out:
# str

# %%
x = int(x)

# %%
type(x)
# Out:
# int

# %%
print(x-34)
# Out:
# -27

# %%
a = float(input("Enter a real number :"))
# Out:
# Enter a real number :5

# %%
type(a)
# Out:
# float

# %%
help(pow)
# Out:
# Help on built-in function pow in module builtins:
#
# pow(base, exp, mod=None)
#     Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
#     Some types, such as ints, are able to use a more efficient algorithm when
#     invoked using the three argument form.

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplentedError if active frontend doesn't support stdin.

# %% [markdown]
# ## Flow control -- if-else statement

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
    print("I am still inside if condition")
print("I am outside the if condition")
# Out:
# 2
# 4
# I am outside the if condition

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
if b>a:
    print(b)
# Out:
# 7
# 8
# 8

# %%
a = int(input())
b = int(input())
if a>b:
    print(a)
    print("if part")
else:
    print(b)
    print("else part")
# Out:
# 8
# 8
# 8
# else part

# %%
a = 10
b = 10
if a==b:
    print("Equal")
elif a>b:
    print("A")
else:
    print("B")
print("Not in if")
# Out:
# Equal
# Not in if

# %%
a = int(input("Enter Marks :"))
if a >= 85:
    print("A Grade")
elif (a < 85) and (a >= 80):
    print("A- Grade")
elif a < 80 and a >= 75:
    print("B Grade")
elif a < 75 and a >= 70:
    print("B- Grade")
else:
    print("Below Average")
# Out:
# Enter Marks :76
# B Grade

# %%
a = 13
if a>10:
    print(">10")
elif not(a>10):
    print("Else part")
# Out:
# >10

# %%
a = int(input())
if a>10:
    print(">10")
    print("Inside the top if")
    if a>20:
        print(">20")
        print("Inside the nested if")
        if a>30:
            print(">30")
            print("inside the nested if of nested if")
        else:
            print("<=30")
            print("inside the else part of nested if of nested if")
    else:
        print("<=20")
        print("Inside the else part of nested if")
print("Outside all ifs")
# Out:
# 65
# >10
# Inside the top if
# >20
# Inside the nested if
# >30
# inside the nested if of nested if
# Outside all ifs

# %%
# single line comment
""" 
User will enter a floating point number let say 238.915. Your task
is to find out the integer portion before the point (in this case 238)
and then check if that integer portion is an even number or not?
"""
x = float(input("Enter a real number :"))
y = round(x)
if x>0:    
    if y>x:
        intPortion = y-1 # 29.6
    else:
        intPortion = y
else:
    if y<x:
        intPortion = y+1
    else:
        intPortion = y

if intPortion%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a real number :4
# Even

# %%
round(-9.3)
# Out:
# -9

# %%
round(-9.6)
# Out:
# -10

# %% [markdown]
# ## While loop

# %%
n = int(input())
i = 1
while i < n:
    print(i**2)
    print("This is iteration number :", i)
    i+=1 # i = i+1
print("Loop done")
# Out:
# 3
# 1
# This is iteration number : 1
# 4
# This is iteration number : 2
# Loop done

# %% [markdown]
# ## Nestest loops

# %%
n = 10
i = 1
while True:
    if i%9 == 0:
        print("Inside if")
        break
    else:
        print("inside Else")
        i = i+1 # i+=1
print("done")
# Out:
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# inside Else
# Inside if
# done

# %%
n = 10
i = 1
while True:
    if i%9 != 0:
        print("inside if")
        i +=1
        continue
    print("something")
    print("somethingelse")
    break
    
print("done")
# Out:
# inside if
# inside if
# inside if
# inside if
# inside if
# inside if
# inside if
# inside if
# something
# somethingelse
# done

# %% [markdown]
# ## For loops

# %%
# For loops iterate through all elemetns in a given list and does some operations
L = []
for i in range(1,20,3):
    print(i)
    L.append(i**2)
print(L)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# [1, 16, 49, 100, 169, 256, 361]

# %%
S = {"apple",4.9,"cherry"}
i = 1
for x in S:
    print(x)
    i+=1
    if i==3:
        break
    else:
        pass
else:
    print("Loop terminates with success")
print("Out side the loop")
# Out:
# cherry
# 4.9
# Out side the loop

# %%
D = {"A":10,"B":-19,"C":"abc"}
for x in D:
    print(x,D[x])
# Out:
# A 10
# B -19
# C abc

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
L = [1,2,4,-5,7,9,3,2]
for j in range(len(L)):
    m = L[j]
    idx = j
    c = j
    for i in range(j,len(L)):
        if L[i]<m:
            m = L[i]
            idx = c
        c+=1    
    tmp = L[j]
    L[j] = m
    L[idx] = tmp
print(L)
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %%
L
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %% [markdown]
# ## Functions

# %% [markdown]
# Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
# that contains all the items in sorted order from min to max. i.e. your
# result will be another list like [-5,1,2,2,3,7,9]

# %%
def findMin(L,startIndx):
    m = L[startIndx]
    idx = startIndx    
    for i in range(startIndx,len(L)):
        x = L[i]
        if x<m:
            m = x
            idx = i
        else:
            pass                
    return m,idx

# %%
a,b = findMin([2,3,4,0,9],1)

# %%
print(a,b)
# Out:
# 0 3

# %% [markdown]
# A function that can swap elements in a list

# %%
def swapValues(L,idx1,idx2):
    tmp = L[idx1]
    L[idx1] = L[idx2]
    L[idx2] = tmp
    return L

# %%
L = [2,3,6,7]
L2 = swapValues(L,1,3)
print(L2)
# Out:
# [2, 7, 6, 3]
